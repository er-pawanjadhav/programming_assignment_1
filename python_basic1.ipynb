# %%
print("hello python")
# Out:
# hello python

# %%
a=10
b=20
print(a+b)
print(a-b)
# Out:
# 30
# -10

# %%
r=20
print("area of triangle is",3.14*r*r)
# Out:
# area of triangle is 1256.0

# %%
a=10
b=20
print("values before swapping",a,b)
c=a
a=b
b=c
print(f"values after swapping {a} {b}")
# Out:
# values before swapping 10 20
# values after swapping 20 10

# %%
import random

print(random.random())
# Out:
# 0.662163841646737
